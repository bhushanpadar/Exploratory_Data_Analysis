# %% [markdown]
# # importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Loading Dataset

# %%
df = pd.read_csv("accident2018.csv")

# %%
df.head()
# Out:
#   Reference Number  Easting  Northing  Number of Vehicles Accident Date  \
# 0          5131732   415809    422277                   2    03/01/2018
# 1          5140196   414478    422719                   2    04/01/2018
# 2          5151479   411718    427905                   2    05/01/2018
# 3          51A0239   409779    425728                   2    10/01/2018
# 4        5.10E+227   416632    422355                   4    14/01/2018
#
#    Time (24hr) 1st Road Class Road Surface  \
# 0         2054   Unclassified   Wet / Damp
# 1          551              A   Wet / Damp
# 2         1650   Unclassified   Wet / Damp
# 3          744              A   Wet / Damp
# 4          348       Motorway   Wet / Damp
#
#                        Lighting Conditions          Weather Conditions  ...  \
# 0  Darkness: street lights present and lit  Raining without high winds  ...
# 1  Darkness: street lights present and lit  Raining without high winds  ...
# ...

# %%
df.shape
# Out:
# (314, 40)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 314 entries, 0 to 313
# Data columns (total 40 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Reference Number     314 non-null    object
#  1   Easting              314 non-null    int64
#  2   Northing             314 non-null    int64
#  3   Number of Vehicles   314 non-null    int64
#  4   Accident Date        314 non-null    object
#  5   Time (24hr)          314 non-null    int64
#  6   1st Road Class       314 non-null    object
#  7   Road Surface         314 non-null    object
#  8   Lighting Conditions  314 non-null    object
#  9   Weather Conditions   314 non-null    object
#  10  Type of Vehicle 1    314 non-null    object
#  11  Casualty Class 1     314 non-null    object
#  12  Casualty Severity 1  314 non-null    object
#  13  Sex of Casualty 1    314 non-null    object
#  14  Age of Casualty 1    314 non-null    int64
# ...

# %%
df.isnull().sum()
# Out:
# Reference Number         0
# Easting                  0
# Northing                 0
# Number of Vehicles       0
# Accident Date            0
# Time (24hr)              0
# 1st Road Class           0
# Road Surface             0
# Lighting Conditions      0
# Weather Conditions       0
# Type of Vehicle 1        0
# Casualty Class 1         0
# Casualty Severity 1      0
# Sex of Casualty 1        0
# Age of Casualty 1        0
# Type of Vehicle 2      101
# Casualty Class 2        92
# Casualty Severity 2     92
# Sex of Casualty 2       92
# Age of Casualty 2       92
# Type of Vehicle 3      280
# Casualty Class 3       264
# Casualty Severity 3    264
# Sex of Casualty 3      264
# Age of Casualty 3      264
# Type of Vehicle 4      303
# Casualty Class 4       298
# Casualty Severity 4    298
# Sex of Casualty 4      298
# Age of Casualty 4      298
# Type of Vehicle 5      311
# Casualty Class 5       307
# Casualty Severity 5    307
# Sex of Casualty 5      307
# ...

# %%
df = df.iloc[0: ,0:15]

# %%
df.shape
# Out:
# (314, 15)

# %%
df.sample(10)
# Out:
#     Reference Number  Easting  Northing  Number of Vehicles Accident Date  \
# 239          5A80001   412459    425485                   2    08/10/2018
# 210          5971462   416401    422144                   2    07/09/2018
# 294          5C81534   406210    423680                   2    08/12/2018
# 119          5610656   401689    415677                   4    01/06/2018
# 92           54O1465   409652    421066                   1    24/04/2018
# 254          5AK1374   408665    425248                   2    20/10/2018
# 241          5A81323   398720    414672                   2    08/10/2018
# 1            5140196   414478    422719                   2    04/01/2018
# 135          56G1182   400634    415258                   2    16/06/2018
# 102          55F0301   409426    423450                   1    15/05/2018
#
#      Time (24hr) 1st Road Class Road Surface  \
# 239         1035              A          Dry
# 210         1711       Motorway          Dry
# ...

# %%
df.columns
# Out:
# Index(['Reference Number', 'Easting', 'Northing', 'Number of Vehicles',
#        'Accident Date', 'Time (24hr)', '1st Road Class', 'Road Surface',
#        'Lighting Conditions', 'Weather Conditions', 'Type of Vehicle 1',
#        'Casualty Class 1', 'Casualty Severity 1', 'Sex of Casualty 1',
#        'Age of Casualty 1'],
#       dtype='object')

# %% [markdown]
# # Drop Uwanted Features

# %%
df.drop(columns = ['Reference Number','Easting','Northing'],inplace=True)

# %%
df.drop('Time (24hr)',axis=1,inplace=True)

# %%
df.head()
# Out:
#    Number of Vehicles Accident Date 1st Road Class Road Surface  \
# 0                   2    03/01/2018   Unclassified   Wet / Damp
# 1                   2    04/01/2018              A   Wet / Damp
# 2                   2    05/01/2018   Unclassified   Wet / Damp
# 3                   2    10/01/2018              A   Wet / Damp
# 4                   4    14/01/2018       Motorway   Wet / Damp
#
#                        Lighting Conditions          Weather Conditions  \
# 0  Darkness: street lights present and lit  Raining without high winds
# 1  Darkness: street lights present and lit  Raining without high winds
# 2  Darkness: street lights present and lit     Fine without high winds
# 3          Daylight: street lights present     Fine without high winds
# 4        Darkness: street lighting unknown     Fine without high winds
#
#                       Type of Vehicle 1 Casualty Class 1 Casualty Severity 1  \
# ...

# %% [markdown]
# # Feature Engineering

# %%
df['Accident_Year'] = df['Accident Date'].apply(lambda x:x.split("/")[2])

# %%
df.head()
# Out:
#    Number of Vehicles Accident Date 1st Road Class Road Surface  \
# 0                   2    03/01/2018   Unclassified   Wet / Damp
# 1                   2    04/01/2018              A   Wet / Damp
# 2                   2    05/01/2018   Unclassified   Wet / Damp
# 3                   2    10/01/2018              A   Wet / Damp
# 4                   4    14/01/2018       Motorway   Wet / Damp
#
#                        Lighting Conditions          Weather Conditions  \
# 0  Darkness: street lights present and lit  Raining without high winds
# 1  Darkness: street lights present and lit  Raining without high winds
# 2  Darkness: street lights present and lit     Fine without high winds
# 3          Daylight: street lights present     Fine without high winds
# 4        Darkness: street lighting unknown     Fine without high winds
#
#                       Type of Vehicle 1 Casualty Class 1 Casualty Severity 1  \
# ...

# %%
df.drop('Accident Date',axis=1,inplace=True)

# %%
df.head()
# Out:
#    Number of Vehicles 1st Road Class Road Surface  \
# 0                   2   Unclassified   Wet / Damp
# 1                   2              A   Wet / Damp
# 2                   2   Unclassified   Wet / Damp
# 3                   2              A   Wet / Damp
# 4                   4       Motorway   Wet / Damp
#
#                        Lighting Conditions          Weather Conditions  \
# 0  Darkness: street lights present and lit  Raining without high winds
# 1  Darkness: street lights present and lit  Raining without high winds
# 2  Darkness: street lights present and lit     Fine without high winds
# 3          Daylight: street lights present     Fine without high winds
# 4        Darkness: street lighting unknown     Fine without high winds
#
#                       Type of Vehicle 1 Casualty Class 1 Casualty Severity 1  \
# 0                                   Car  Driver or rider              Slight
# 1                                   Car  Driver or rider              Slight
# ...

# %%
df.columns
# Out:
# Index(['Number of Vehicles', '1st Road Class', 'Road Surface',
#        'Lighting Conditions', 'Weather Conditions', 'Type of Vehicle 1',
#        'Casualty Class 1', 'Casualty Severity 1', 'Sex of Casualty 1',
#        'Age of Casualty 1', 'Accident_Year'],
#       dtype='object')

# %%
df.rename(columns = {'1st Road Class':'Road_Class','Type of Vehicle 1':'Vehicle_Type',
                     'Casualty Class 1':'Casualty_Class','Casualty Severity 1':'Casualty_Severity',
                     'Sex of Casualty 1':'Sex_of_Casualty','Age of Casualty 1':'Age_of_Casualty'},inplace=True)

# %%
df.head()
# Out:
#    Number of Vehicles    Road_Class Road Surface  \
# 0                   2  Unclassified   Wet / Damp
# 1                   2             A   Wet / Damp
# 2                   2  Unclassified   Wet / Damp
# 3                   2             A   Wet / Damp
# 4                   4      Motorway   Wet / Damp
#
#                        Lighting Conditions          Weather Conditions  \
# 0  Darkness: street lights present and lit  Raining without high winds
# 1  Darkness: street lights present and lit  Raining without high winds
# 2  Darkness: street lights present and lit     Fine without high winds
# 3          Daylight: street lights present     Fine without high winds
# 4        Darkness: street lighting unknown     Fine without high winds
#
#                            Vehicle_Type   Casualty_Class Casualty_Severity  \
# 0                                   Car  Driver or rider            Slight
# 1                                   Car  Driver or rider            Slight
# ...

# %% [markdown]
# # Checking Value counts of each Categorical Feature

# %%
df['Number of Vehicles'].value_counts()
# Out:
# 2    179
# 1    101
# 3     23
# 4      8
# 6      2
# 5      1
# Name: Number of Vehicles, dtype: int64

# %%
df['Road_Class'].value_counts()
# Out:
# Unclassified    154
# A               124
# Motorway         29
# B                 7
# Name: Road_Class, dtype: int64

# %%
df['Road Surface'].value_counts()
# Out:
# Dry            221
# Wet / Damp      78
# Snow            11
# Frost / Ice      4
# Name: Road Surface, dtype: int64

# %%
df['Lighting Conditions'].value_counts()
# Out:
# Daylight: street lights present              229
# Darkness: street lights present and lit       74
# Darkness: no street lighting                   5
# Darkness: street lighting unknown              4
# Darkness: street lights present but unlit      2
# Name: Lighting Conditions, dtype: int64

# %%
df['Weather Conditions'].value_counts()
# Out:
# Fine without high winds       258
# Raining without high winds     35
# Snowing without high winds      7
# Other                           3
# Fine with high winds            3
# Snowing with high winds         3
# Fog or mist – if hazard         3
# Raining with high winds         2
# Name: Weather Conditions, dtype: int64

# %%
df['Vehicle_Type'].value_counts()
# Out:
# Car                                                       238
# Goods vehicle 3.5 tonnes mgw and under                     17
# Pedal cycle                                                14
# Taxi/Private hire car                                      12
# Motorcycle over 50cc and up to 125cc                        9
# Bus or coach (17 or more passenger seats)                   6
# Motorcycle over 500cc                                       5
# Goods vehicle 7.5 tonnes mgw and over                       4
# Motorcycle over 125cc and up to 500cc                       3
# M/cycle 50cc and under                                      2
# Goods vehicle over 3.5 tonnes and under 7.5 tonnes mgw      2
# Mobility Scooter                                            1
# Other Vehicle                                               1
# Name: Vehicle_Type, dtype: int64

# %%
df['Casualty_Class'].value_counts()
# Out:
# Driver or rider                 204
# Pedestrian                       70
# Vehicle or pillion passenger     40
# Name: Casualty_Class, dtype: int64

# %%
df['Casualty_Severity'].value_counts()
# Out:
# Slight     253
# Serious     57
# Fatal        4
# Name: Casualty_Severity, dtype: int64

# %%
df['Sex_of_Casualty'].value_counts()
# Out:
# Male      191
# Female    123
# Name: Sex_of_Casualty, dtype: int64

# %% [markdown]
# # Checking Data Distribution of Numerical column

# %%
sns.histplot(data=df, x=df['Age_of_Casualty'])
# Out:
# <AxesSubplot: xlabel='Age_of_Casualty', ylabel='Count'>

# %%
df.head()
# Out:
#    Number of Vehicles    Road_Class Road Surface  \
# 0                   2  Unclassified   Wet / Damp
# 1                   2             A   Wet / Damp
# 2                   2  Unclassified   Wet / Damp
# 3                   2             A   Wet / Damp
# 4                   4      Motorway   Wet / Damp
#
#                        Lighting Conditions          Weather Conditions  \
# 0  Darkness: street lights present and lit  Raining without high winds
# 1  Darkness: street lights present and lit  Raining without high winds
# 2  Darkness: street lights present and lit     Fine without high winds
# 3          Daylight: street lights present     Fine without high winds
# 4        Darkness: street lighting unknown     Fine without high winds
#
#                            Vehicle_Type   Casualty_Class Casualty_Severity  \
# 0                                   Car  Driver or rider            Slight
# 1                                   Car  Driver or rider            Slight
# ...

# %% [markdown]
# # Encoding Categorical Features

# %%
from sklearn.preprocessing import LabelEncoder

# %%
Label_Enc = LabelEncoder()

# %%
df['Road_Class'] = Label_Enc.fit_transform(df['Road_Class'])

# %%
for col in ['Lighting Conditions','Weather Conditions','Vehicle_Type','Casualty_Class','Casualty_Severity','Sex_of_Casualty']:
    df[col] = Label_Enc.fit_transform(df[col])

# %%
df.head()
# Out:
#    Number of Vehicles  Road_Class Road Surface  Lighting Conditions  \
# 0                   2           3   Wet / Damp                    2
# 1                   2           0   Wet / Damp                    2
# 2                   2           3   Wet / Damp                    2
# 3                   2           0   Wet / Damp                    4
# 4                   4           2   Wet / Damp                    1
#
#    Weather Conditions  Vehicle_Type  Casualty_Class  Casualty_Severity  \
# 0                   5             1               0                  2
# 1                   5             1               0                  2
# 2                   1             1               0                  2
# 3                   1             9               0                  2
# 4                   1             1               0                  2
#
#    Sex_of_Casualty  Age_of_Casualty Accident_Year
# 0                1               25          2018
# ...

# %%
df['Road Surface'] = Label_Enc.fit_transform(df['Road Surface'])

# %%
df.head()
# Out:
#    Number of Vehicles  Road_Class  Road Surface  Lighting Conditions  \
# 0                   2           3             3                    2
# 1                   2           0             3                    2
# 2                   2           3             3                    2
# 3                   2           0             3                    4
# 4                   4           2             3                    1
#
#    Weather Conditions  Vehicle_Type  Casualty_Class  Casualty_Severity  \
# 0                   5             1               0                  2
# 1                   5             1               0                  2
# 2                   1             1               0                  2
# 3                   1             9               0                  2
# 4                   1             1               0                  2
#
#    Sex_of_Casualty  Age_of_Casualty Accident_Year
# 0                1               25          2018
# ...

# %%
sns.pairplot(df)

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# C:\Users\SHREE\AppData\Local\Temp\ipykernel_8856\4277794465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <AxesSubplot: >
